# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
chrome_driver_path = "C:/Users/NOOMAN KHAN/OneDrive/Documents/Selenium/chromedriver.exe"
driver = webdriver.Chrome(executable_path = chrome_driver_path)
driver.get("https://www.linkedin.com/jobs/search/?currentJobId=3443289270&geoId=102713980&keywords=data%20analyst&location=India&refresh=true")
sign_in_button = driver.find_element(By.LINK_TEXT , "Sign in")
sign_in_button.click()
username = driver.find_element(By.ID , "username")
username.send_keys("khannooman384@gmail.com")
password = driver.find_element(By.ID , "password")
password.send_keys("Nooman@#123")
password.send_keys(Keys.ENTER)
# Out:
# C:\Users\NOOMAN KHAN\AppData\Local\Temp\ipykernel_11888\9547088.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = chrome_driver_path)

# %%
jobs = []
for i in range(1,10):
    driver.find_element(By.XPATH, f'//button[@aria-label="Page {i}"]')
    soup = BeautifulSoup(driver.page_source , 'lxml')
    for i in soup.find_all('a' , href = True):
        if "/jobs/view" in i["href"]:
            jobs.append(i["href"])

# %%
jobs
# Out:
# ['/jobs/view/3427620388/?eBP=CwEAAAGFyRa_ITMBPWuoDphZmPyn2LAb8LSjYQPhSm5KEXyHvL-Cs4mGCE0LIUIeKyPMkb87cHQISKlAvCiAtLKjpk77n9xkbGzsXlk1IVuCaE4XQZ7Z2W5YYaEj1nWC2YdTVKPjI4WekI_3V0GnnR6c1PmyAN21CR9T6qLqlgt7IYRk6NaDE4Zge0q2ro96RDKT9bzjoEOgYtzZiVusKuGSQ2ErHcDWL8BS-FIMwyRuvj-W6uGtP2Str3mWX8cJkohJBhXA8bTXLOn_QiRjMXHKwnnB9hgO3mjlPXxu6e_8GBYYaSvi4C61ewdiCcXbM-aJhsv4qXTbJIzoamSxYHM6ZzE6QPFo7LM&recommendedFlavor=IN_NETWORK&refId=E1odD2Lg%2BTqCX%2F%2BpBiZmiQ%3D%3D&trackingId=XpOhrFI0dPdmp10Mshemug%3D%3D&trk=flagship3_search_srp_jobs',
# ...

# %%
baseurl = "https://www.linkedin.com/"
job = []
Location = []
Company = []
Upload = []

for i in jobs:
    driver.get(f'{baseurl}{i}')
    soup = BeautifulSoup(driver.page_source , 'lxml')
    job.append(soup.find("h1").text)
    Company.append(soup.select_one("span a").text)
    Location.append(driver.find_element(By.CLASS_NAME , "jobs-unified-top-card__bullet").text)
    Upload.append(driver.find_element(By.CLASS_NAME , 'jobs-unified-top-card__posted-date').text)

# %%
dic  = {"job":job,
     "Location":Location,
     "Company":Company,
      "Upload":Upload}

df1 =  pd.DataFrame(dic)
df1
# Out:
#                                          job                     Location  \
# 0               Associate II - Data Analysis  Bengaluru, Karnataka, India
# 1  Business Intelligence Analyst, Operations  Bengaluru, Karnataka, India
# 2  Process Developer– Data Analyst-COR021705  Noida, Uttar Pradesh, India
# 3            Business Intelligence Analyst 2   Chennai, Tamil Nadu, India
# 4                               Data Analyst        Surat, Gujarat, India
#
#                                              Company
# 0      \n                    UST\n
# 1    \n                    Calix\n
# 2  \n                    Genpact\n
# 3  \n                    Comcast\n
# 4  \n                    AFIV DATA OUTSOURCING\n ...

# %%
Location
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '\n    You are on the messaging overlay. Press enter to open the list of conversations.\n',
#  '',
#  '\n    You are on the messaging overlay. Press enter to open the list of conversations.\n',
#  '\n    You are on the messaging overlay. Press enter to open the list of conversations.\n',
#  '',
#  '',
#  '\n    You are on the messaging overlay. Press enter to open the list of conversations.\n',
#  '',
#  '\n    You are on the messaging overlay. Press enter to open the list of conversations.\n',
#  '\n    You are on the messaging overlay. Press enter to open the list of conversations.\n',
#  '\n    You are on the messaging overlay. Press enter to open the list of conversations.\n',
#  '\n    You are on the messaging overlay. Press enter to open the list of conversations.\n',
#  '',
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

chrome_driver_path = "C:/Users/NOOMAN KHAN/OneDrive/Documents/Selenium/chromedriver.exe"
driver = webdriver.Chrome(executable_path=chrome_driver_path)
driver.get("https://www.adamchoi.co.uk/overs/detailed")
all_mathes_button = driver.find_element(By.XPATH , '//label[@analytics-event = "All matches" ]')
all_mathes_button.click()
matches = driver.find_elements(By.TAG_NAME , "tr")

date = []
home_team = []
score = []
away_team = []
for match in matches:
    date.append(match.find_element(By.XPATH , "./td[1]").text)
    home_team.append(match.find_element(By.XPATH , "./td[2]").text)
    score.append(match.find_element(By.XPATH , "./td[3]").text)
    away_team.append(match.find_element(By.XPATH , "./td[4]").text)
    
details = {"date":date,
          "home_team":home_team,
          "score":score,
          "away_team":away_team}
import pandas as pd
df = pd.DataFrame(details)
df
# Out:
# C:\Users\NOOMAN KHAN\AppData\Local\Temp\ipykernel_11888\3285424240.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=chrome_driver_path)
#            date       home_team  score    away_team
# 0    05-08-2022  Crystal Palace  0 - 2      Arsenal
# 1    13-08-2022         Arsenal  4 - 2    Leicester
# 2    20-08-2022     Bournemouth  0 - 3      Arsenal
# 3    27-08-2022         Arsenal  2 - 1       Fulham
# 4    31-08-2022         Arsenal  2 - 1  Aston Villa
# ..          ...             ...    ...          ...
# 387  12-11-2022          Wolves  0 - 2      Arsenal
# 388  26-12-2022         Everton  1 - 2       Wolves
# 389  31-12-2022          Wolves  0 - 1   Man United
# 390  04-01-2023     Aston Villa  1 - 1       Wolves
# 391  14-01-2023          Wolves  1 - 0     West Ham
#
# [392 rows x 4 columns]

# %%
# scrap bikedekho

bike = []
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
chrome_driver_path = "C:/Users/NOOMAN KHAN/OneDrive/Documents/Selenium/chromedriver.exe"
driver = webdriver.Chrome(executable_path = chrome_driver_path)
driver.get("https://www.bikedekho.com/latest-bikes")
soup = BeautifulSoup(driver.page_source)
for i in soup.find_all("a" , "title truncate",href = True):
    bike.append(i["href"])

Name = []
Price = []
Engine = []
Power = []
Torque = []
Break = []
Tyre_Type = []
ABS = []
baseurl = "https://www.bikedekho.com"

for i in bike:
    driver.get(f"{baseurl}{i}")
    soups = BeautifulSoup(driver.page_source)
    Name.append(soups.find("h1").text)
    Price.append(driver.find_element(By.TAG_NAME , "i").text)
    try:
        Engine.append(driver.find_element(By.XPATH , "//tr[1]/td[2]").text)
        Power.append(driver.find_element(By.XPATH , "//tr[2]/td[2]").text)
        Torque.append(driver.find_element(By.XPATH , "//tr[3]/td[2]").text)
        Break.append(driver.find_element(By.XPATH , "//tr[4]/td[2]").text)
        Tyre_Type.append(driver.find_element(By.XPATH , "//tr[5]/td[2]").text)
        ABS.append(driver.find_element(By.XPATH , "//tr[6]/td[2]").text)
    except:
        Engine.append(" ")
        Power.append(" ")
        Torque.append(" ")
        Break.append(" ")
        Tyre_Type.append(" ")
        ABS.append(" ")
# Out:
# C:\Users\NOOMAN KHAN\AppData\Local\Temp\ipykernel_23964\3009806387.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = chrome_driver_path)

# %%
for i in dic.values():
    print(len(i))
    print(i)
# Out:
# 15
# ['Royal Enfield Super Meteor 650', 'Joy e-bike Mihos', 'Keeway SR 250', 'Aeroride YB2000', 'Deltic ZGS', 'Aeroride E-Spark', 'Deltic Legion', 'Aeroride Bravo', 'Aeroride Aero', 'Evtric Rise', 'Deltic Trento', 'Avera Retrosa Lite E', 'Hero Xpluse 200T 4V STD', 'Bajaj Platina 110 ABS', 'Ducati DesertX']
# 15
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# 18
# ['648 cc', '100 km/charge', '223 cc', '80-120 km/charge', ' ', '70 km/charge', '60 V / 30 Ah', ' ', '70 -100 km/charge', '90-110 km/charge', '60-100 km/charge', ' ', '100-110 km/charge', '75 km/charge', 'Rs.88,900', 'Rs.1,38,496', 'Rs.72,224', '937 cc']
# 18
# ['47 PS', '74 V / 40 Ah', '16.22 PS', '72 V / 26 Ah', ' ', '72 V / 30 Ah', 'Digital', ' ', '60.8 V / 30 Ah', '72 V / 48 Ah', '60 V / 30 Ah', ' ', '72 V / 40 Ah', '72 V / 36 Ah', 'Rs.4,052', 'Rs.11,380', 'Rs.6,308', '111.52 PS']
# 18
# ...

# %%
dic = {
    "Name":Name,
    "Price":Price,
    "Engine":Engine,
    "Power":Power,
    "Torque":Torque,
    "Break":Break,
    "Tyre_Type":Tyre_Type,
    "ABS":ABS
    
    
    
}

# %%
import pandas as pd
df2 = pd.DataFrame(dic)

# %%
Price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a58ff69d89a9fad1160f4c2686f4ae7", element="27b379f9-85db-4bb0-9bdf-ef29f1953984")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a58ff69d89a9fad1160f4c2686f4ae7", element="4e7d036d-a859-40f0-b357-60a0cbe40dde")>]

# %%
# scrap amazon all mobile
phone = []
for i in range(1,21):
    from bs4 import BeautifulSoup
    from selenium import webdriver
    from selenium.webdriver.common.keys import Keys
    from selenium.webdriver.common.by import By
    chrome_driver_path = "C:/Users/NOOMAN KHAN/OneDrive/Documents/Selenium/chromedriver.exe"
    driver = webdriver.Chrome(executable_path = chrome_driver_path)

    driver.get(f"https://www.amazon.in/s?k=phone&crid=37P9RWUHHW2QB&qid=1674146952&sprefix=phone%2Caps%2C480&ref=sr_pg_{i}")
    soup  = BeautifulSoup(driver.page_source)
    for i in soup.find_all("a" , href = True):
        if "/sspa/click" in i["href"]:
            if i not in phone:
                phone.append(i["href"])
# Out:
# C:\Users\NOOMAN KHAN\AppData\Local\Temp\ipykernel_8912\2217042196.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = chrome_driver_path)

# %%
len(phone)
# Out:
# 540

# %%
lis[15]
# Out:
# '\n                \u200e6000 '

# %%
dic = {
    "Name":Name,
    "price":price,
    "Ratings":Ratings,
    "Brand":Brand,
    "Number_of_ratings":Number_of_ratings,
    
    "OS":OS,
    "RAM":RAM,
    "dimension":dimension,
    "battries":battries,
    "special_feature":special_feature,
    "Wireless_communication_technologies":Wireless_communication_technologies,
    "Cemra":Cemra,
    "Battery":Battery,
    "Ratings":Ratings}

# %%
dic
# Out:
# {'Name': ['        Samsung Galaxy M53 5G (Mystique Green, 8GB, 128GB Storage) | 108MP | sAmoled+ 120Hz | 16GB RAM with RAM Plus | Travel Adapter to be Purchased Separately       ',
#   '        Samsung Galaxy M53 5G (Mystique Green, 8GB, 128GB Storage) | 108MP | sAmoled+ 120Hz | 16GB RAM with RAM Plus | Travel Adapter to be Purchased Separately       ',
#   '        Apple iPhone 5s (16GB,Space Grey)       ',
#   '        Samsung Galaxy M53 5G (Mystique Green, 8GB, 128GB Storage) | 108MP | sAmoled+ 120Hz | 16GB RAM with RAM Plus | Travel Adapter to be Purchased Separately       '],
#  'price': ['25,999.', '25,999.', '13,499.', '25,999.'],
#  'Ratings': ['3.9 out of 5 stars',
#   '3.9 out of 5 stars',
#   '1.0 out of 5 stars',
#   '3.9 out of 5 stars'],
#  'Brand': ['Samsung', 'Samsung', 'CEX', 'Samsung'],
#  'Number_of_ratings': ['9 ratings', '9 ratings', '9 ratings', '9 ratings'],
#  'OS': ['\n                \u200eAndroid 12.0 ',
#   '\n                \u200eAndroid 12.0 ',
# ...
